# %%
# !nvidia-smi
# Out:
# Wed Mar 27 16:09:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.161.07             Driver Version: 535.161.07   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1080 Ti     Off | 00000000:01:00.0  On |                  N/A |
# |  0%   50C    P8              22W / 275W |    789MiB / 11264MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.9 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# Setup complete ✅ (8 CPUs, 62.7 GB RAM, 213.1/915.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir datasets
# %cd datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="CMAK5iHcwcUzZLqrain4")
project = rf.workspace("rudra-vhs8a").project("cell-detection-qsblz")
version = project.version(1)
dataset = version.download("yolov8")
# %cd ..
# Out:
# mkdir: cannot create directory ‘datasets’: File exists
# /home/vplab/Desktop/kanth/YOLOv8/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# /home/vplab/Desktop/kanth/YOLOv8

# %%
# %ls
# Out:
# 14880.jpg  datasets/  runs/  Yolov8.ipynb  yolov8n.pt  yolov8s.pt

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/home/vplab/Desktop/kanth/YOLOv8/datasets/cell-detection-1/data.yaml epochs=25 imgsz=800 plots=True project=YOLOv8-F name=main
# Out:
# New https://pypi.org/project/ultralytics/8.1.34 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.9 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# ...

# %%
# !yolo task=detect mode=predict model=YOLOv8/train/weights/best.pt conf=0.25 source=14880.jpg save=True show_labels=False
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.9 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11169MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /home/vplab/Desktop/kanth/YOLOv8/14880.jpg: 800x800 300 cells, 11.0ms
# Speed: 4.8ms preprocess, 11.0ms inference, 292.2ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to /home/vplab/Desktop/kanth/celldetection/runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/home/vplab/Desktop/kanth/celldetection/runs/detect/predict3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
